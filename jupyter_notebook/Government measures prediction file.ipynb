# %% [markdown]
# ## Government Measures file generation

# %%
import pandas as pd

# %%
argentina_dataframe = pd.read_csv('../Gov measures file country wise/Argentina_Modeling_result.csv')
argentina_dataframe
# Out:
#      COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  Argentina                 7                  Public health measures
# 1  Argentina                 7                   Movement restrictions
# 2  Argentina                 7                       Social distancing
# 3  Argentina                 7                                Lockdown
# 4  Argentina                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                   7
# 1                  11
# 2                   4
# 3                   2
# 4                   6

# %%
australia_dataframe = pd.read_csv('../Gov measures file country wise/Australia_Modeling_result.csv')
australia_dataframe
# Out:
#      COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  Australia                 7                  Public health measures
# 1  Australia                 7                   Movement restrictions
# 2  Australia                 7                       Social distancing
# 3  Australia                 7                                Lockdown
# 4  Australia                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  26
# 1                  15
# 2                  11
# 3                   4
# 4                   9

# %%
brazil_dataframe = pd.read_csv('../Gov measures file country wise/Brazil_Modeling_result.csv')
brazil_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  Brazil                 7                  Public health measures
# 1  Brazil                 7                   Movement restrictions
# 2  Brazil                 7                       Social distancing
# 3  Brazil                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                   7
# 1                  10
# 2                   4
# 3                   1

# %%
canada_dataframe = pd.read_csv('../Gov measures file country wise/Canada_Modeling_result.csv')
canada_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  Canada                 7                  Public health measures
# 1  Canada                 7                   Movement restrictions
# 2  Canada                 7                       Social distancing
# 3  Canada                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  21
# 1                   7
# 2                   1
# 3                  11

# %%
china_dataframe = pd.read_csv('../Gov measures file country wise/China_Modeling_result.csv')
china_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0   China                 7                  Public health measures
# 1   China                 7                   Movement restrictions
# 2   China                 7                       Social distancing
# 3   China                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  18
# 1                   6
# 2                   2
# 3                   4

# %%
france_dataframe = pd.read_csv('../Gov measures file country wise/France_Modeling_result.csv')
france_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  France                 7                  Public health measures
# 1  France                 7                   Movement restrictions
# 2  France                 7                       Social distancing
# 3  France                 7                                Lockdown
# 4  France                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  13
# 1                   4
# 2                   5
# 3                   1
# 4                   9

# %%
germany_dataframe = pd.read_csv('../Gov measures file country wise/Germany_Modeling_result.csv')
germany_dataframe
# Out:
#    COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  Germany                 7                  Public health measures
# 1  Germany                 7                   Movement restrictions
# 2  Germany                 7                       Social distancing
# 3  Germany                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  19
# 1                   6
# 2                   7
# 3                   6

# %%
india_dataframe = pd.read_csv('../Gov measures file country wise/India_Modeling_result.csv')
india_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0   India                 7                  Public health measures
# 1   India                 7                   Movement restrictions
# 2   India                 7                                Lockdown
# 3   India                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  18
# 1                   5
# 2                   1
# 3                   4

# %%
indonesia_dataframe = pd.read_csv('../Gov measures file country wise/Indonesia_Modeling_result.csv')
indonesia_dataframe
# Out:
#      COUNTRY  DURATION(MONTHS)           MAIN_MEASURES  COUNT_OF_INSTANCES
# 0  Indonesia                 7  Public health measures                  14
# 1  Indonesia                 7   Movement restrictions                   3
# 2  Indonesia                 7       Social distancing                   1

# %%
italy_dataframe = pd.read_csv('../Gov measures file country wise/Italy_Modeling_result.csv')
italy_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0   Italy                 7                  Public health measures
# 1   Italy                 7                   Movement restrictions
# 2   Italy                 7                       Social distancing
# 3   Italy                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  18
# 1                   4
# 2                   8
# 3                   5

# %%
japan_dataframe = pd.read_csv('../Gov measures file country wise/Japan_Modeling_result.csv')
japan_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0   Japan                 7                  Public health measures
# 1   Japan                 7                   Movement restrictions
# 2   Japan                 7                       Social distancing
# 3   Japan                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  13
# 1                   7
# 2                   2
# 3                   3

# %%
mexico_dataframe = pd.read_csv('../Gov measures file country wise/Mexico_Modeling_result.csv')
mexico_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  Mexico                 7                  Public health measures
# 1  Mexico                 7                   Movement restrictions
# 2  Mexico                 7                       Social distancing
# 3  Mexico                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  18
# 1                   3
# 2                   7
# 3                   2

# %%
russia_dataframe = pd.read_csv('../Gov measures file country wise/Russia_Modeling_result.csv')
russia_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  Russia                 7                  Public health measures
# 1  Russia                 7                   Movement restrictions
# 2  Russia                 7                       Social distancing
# 3  Russia                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  15
# 1                   5
# 2                   8
# 3                   2

# %%
saudiarabia_dataframe = pd.read_csv('../Gov measures file country wise/Saudi_Arabia_Modeling_result.csv')
saudiarabia_dataframe
# Out:
#         COUNTRY  DURATION(MONTHS)           MAIN_MEASURES  COUNT_OF_INSTANCES
# 0  Saudi Arabia                 7  Public health measures                   9
# 1  Saudi Arabia                 7   Movement restrictions                   8
# 2  Saudi Arabia                 7       Social distancing                   1

# %%
southafrica_dataframe = pd.read_csv('../Gov measures file country wise/South_Africa_Modeling_result.csv')
southafrica_dataframe
# Out:
#         COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  South Africa                 7                  Public health measures
# 1  South Africa                 7                   Movement restrictions
# 2  South Africa                 7                       Social distancing
# 3  South Africa                 7                                Lockdown
# 4  South Africa                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                   7
# 1                   2
# 2                   3
# 3                   1
# 4                   5

# %%
turkey_dataframe = pd.read_csv('../Gov measures file country wise/Turkey_Modeling_result.csv')
turkey_dataframe
# Out:
#   COUNTRY  DURATION(MONTHS)           MAIN_MEASURES  COUNT_OF_INSTANCES
# 0  Turkey                 7  Public health measures                   4
# 1  Turkey                 7   Movement restrictions                  12
# 2  Turkey                 7       Social distancing                   7

# %%
uk_dataframe = pd.read_csv('../Gov measures file country wise/United_Kingdom_Modeling_result.csv')
uk_dataframe
# Out:
#           COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  United Kingdom                 7                  Public health measures
# 1  United Kingdom                 7                   Movement restrictions
# 2  United Kingdom                 7                       Social distancing
# 3  United Kingdom                 7                                Lockdown
# 4  United Kingdom                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  24
# 1                   4
# 2                  11
# 3                   1
# 4                   2

# %%
us_dataframe = pd.read_csv('../Gov measures file country wise/United_States_Modeling_result.csv')
us_dataframe
# Out:
#          COUNTRY  DURATION(MONTHS)                           MAIN_MEASURES  \
# 0  United States                 7                  Public health measures
# 1  United States                 7                   Movement restrictions
# 2  United States                 7                       Social distancing
# 3  United States                 7  Governance and socio-economic measures
#
#    COUNT_OF_INSTANCES
# 0                  18
# 1                   8
# 2                   3
# 3                  11

# %%
final_dataframe = argentina_dataframe

# %%
final_dataframe = final_dataframe.append(australia_dataframe)

# %%
final_dataframe = final_dataframe.append(brazil_dataframe)

# %%
final_dataframe = final_dataframe.append(canada_dataframe)

# %%
final_dataframe = final_dataframe.append(china_dataframe)

# %%
final_dataframe = final_dataframe.append(france_dataframe)

# %%
final_dataframe = final_dataframe.append(germany_dataframe)

# %%
final_dataframe = final_dataframe.append(india_dataframe)

# %%
final_dataframe = final_dataframe.append(indonesia_dataframe)

# %%
final_dataframe = final_dataframe.append(italy_dataframe)

# %%
final_dataframe = final_dataframe.append(japan_dataframe)

# %%
final_dataframe = final_dataframe.append(mexico_dataframe)

# %%
final_dataframe = final_dataframe.append(russia_dataframe)

# %%
final_dataframe = final_dataframe.append(southafrica_dataframe)

# %%
final_dataframe = final_dataframe.append(saudiarabia_dataframe)

# %%
final_dataframe = final_dataframe.append(turkey_dataframe)

# %%
final_dataframe = final_dataframe.append(uk_dataframe)

# %%
final_dataframe = final_dataframe.append(us_dataframe)

# %%
final_dataframe = final_dataframe.drop(['DURATION(MONTHS)'], axis = 1)

# %%
final_dataframe
# Out:
#            COUNTRY                           MAIN_MEASURES  COUNT_OF_INSTANCES
# 0        Argentina                  Public health measures                   7
# 1        Argentina                   Movement restrictions                  11
# 2        Argentina                       Social distancing                   4
# 3        Argentina                                Lockdown                   2
# 4        Argentina  Governance and socio-economic measures                   6
# ..             ...                                     ...                 ...
# 4   United Kingdom  Governance and socio-economic measures                   2
# 0    United States                  Public health measures                  18
# 1    United States                   Movement restrictions                   8
# 2    United States                       Social distancing                   3
# 3    United States  Governance and socio-economic measures                  11
#
# [74 rows x 3 columns]

# %%
# Writing the clean dataframe to csv file
final_dataframe.to_csv('../cleaned_csv/gov_measures_prediction.csv', index=False)
